# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import urllib.request, urllib.error, urllib.parse
import time

# %%
url = 'https://www.alamatbank.com/alamat-kantor-bank-bca-di-seluruh-indonesia/'
label = 'Bank Bca'
resp = requests.get(url)
html = resp.content
soup = bs(html, 'html.parser')
tab = soup.find_all(class_='tabcontent')

# %%
provinsi = []
kota = []
link = []

cabang = []
alamat = []

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import urllib.request, urllib.error, urllib.parse
import time

url = 'https://www.alamatbank.com/alamat-kantor-bank-mandiri-di-seluruh-indonesia/'

label = 'Bank Mandiri'
resp = requests.get(url)
html = resp.content
soup = bs(html, 'html.parser')
tab = soup.find_all(class_='tabcontent')

provinsi = []
kota = []

cabang = []
alamat = []

idx = ['BOB','CO','KP','KW','KANINS','KC','KCU','KCS','KCP','KCPS','KF','KK','KK LPO','KKS','KLN','KLS','KPP','LS','OC','PB','PP','TKA','TKE','ULS','MUR']
print('Scraping ', label, ' has started')

for x in range(len(tab)) :
    col = tab[0]
    prov = col.find_all('h4')
    row = col.find_all('ul')
    for y in range(len(prov)) :
        prov_temp = prov[y].text.strip('\xa0')
        #provinsi.append(prov[y].text.strip('\xa0'))
        a = row[y].find_all('a')
        for b in range(len(a)):
            kota_temp = a[b].text
            time.sleep(10)
            url = a[b]['href']
            
            response = urllib.request.urlopen(url)
            webContent = response.read().decode('UTF-8')
            link_kc = bs(webContent,'html.parser')
            
            '''if len(link_kc.find_all(class_='responsive-tabs')) == 0 :
                tabs = link_kc.find_all(class_='entry-content')
            else : 
                tabs = link_kc.find_all(class_='responsive-tabs')'''
            
            tabs = link_kc.find_all(class_='entry-content')
            for x in range(len(tabs)):
                table = tabs[x].find_all('table')
                for z in range(len(table)):
                    td = table[z].find_all('td')
                    raw_td = []
                    if td[0].text == 'NO' or td[0].text == 'NO.' : 
                        td = td[4:]
                    for q in range(len(td)):
                        if td[q].text == '\xa0' or len(td[q].text) == 0:
                            continue
                        elif td[q].text.split()[0] in idx :
                            raw_td.append(td[q])
                        elif len(td[q].text.split()) <= 2 :
                            continue
                        elif len(td[q].text.split('&')) == 2 :
                            raw_td.append(td[q])
                        elif td[q].text.split()[0].upper() == 'BANK' or td[q].text.split()[0].upper() == 'KANTOR':
                            continue
                        elif len(td[q].text.split()[0].split('-')) == 2 or len(td[q].text.split()[0].split('-')) == 3:
                            continue
                        else :
                            raw_td.append(td[q])
                    
                    for w in range(0,len(raw_td),2):
                        cabang.append(raw_td[w].text)
                        kota.append(kota_temp)
                        provinsi.append(prov_temp)
                        print('Kota :', kota[-1], end='\r')
                        #print('Kota :', kota[-1])
                    for e in range(1,len(raw_td),2):
                        alamat.append(raw_td[e].text)
                    """for r in range(len(cabang)) :
                        kota.append(kota_temp)
                        provinsi.append(prov_temp)"""
                    
                    #break
                #break
            #break
        break
    break

dataframe = pd.DataFrame(columns = ['City','Provinsi','Cabang','Alamat'])
dataframe['City'] = kota
dataframe['Provinsi'] = provinsi
dataframe['Cabang'] = cabang
dataframe['Alamat'] = alamat

cabang_fix = []
for i in range(len(dataframe['Cabang'])) :
    cabang_fix.append(dataframe['Cabang'].str.split('(')[i][0].strip())
dataframe['Cabang'] = cabang_fix

alamat_fix = []
for i in range(len(dataframe['Alamat'])) :
    alamat_fix.append(dataframe['Alamat'][i].replace('\n', ''))

dataframe['Alamat'] = alamat_fix

#dataframe

dataframe.to_csv(label+'.csv', index=False)
dataframe.to_excel(label+'.xlsx', index=False)

print('Scraping '+label+' has finished')
# Out:
# Scraping  Bank Mandiri  has started
# Kota : Jakarta Utaraan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [179], in <cell line: 92>()
#      90 dataframe['Provinsi'] = provinsi
#      91 dataframe['Cabang'] = cabang
# ---> 92 dataframe['Alamat'] = alamat
#      94 cabang_fix = []
#      95 for i in range(len(dataframe['Cabang'])) :
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4535, in DataFrame._sanitize_column(self, value)
#    4532     return _reindex_for_setitem(value, self.index)
#    4534 if is_list_like(value):
# -> 4535     com.require_length_match(value, self.index)
#    4536 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (390) does not match length of index (394)

# %%
cabang_fix = []
for i in range(len(dataframe['Cabang'])) :
    cabang_fix.append(dataframe['Cabang'].str.split('(')[i][0].strip())
    
dataframe['Cabang'] = cabang_fix
dataframe
# Out:
#                City     Provinsi             Cabang  \
# 0     Jakarta Barat  DKI Jakarta         KCU ASEMKA
# 1     Jakarta Barat  DKI Jakarta     KCU DAAN MOGOT
# 2     Jakarta Barat  DKI Jakarta     KCU GAJAH MADA
# 3     Jakarta Barat  DKI Jakarta   KCU GREEN GARDEN
# 4     Jakarta Barat  DKI Jakarta  KCU KEDOYA PERMAI
# ...             ...          ...                ...
# 1082         Timika        Papua         KCP Timika
# 1083       Jayapura        Papua       KCU JAYAPURA
# 1084       Jayapura        Papua        KCP Abepura
# 1085       Jayapura        Papua      KCP Manokwari
# 1086         Sorong  Papua Barat         KCP Sorong
#
#                                                  Alamat
# 0          Jln. Asemka 27-30 \n Jakarta Barat, JK 11110
# 1     Jln. Daan Mogot No. 95 \n Jakarta Barat, JK 11460
# 2     Jln. Gajah Mada 112 B-C-D \n Jakarta Barat, JK...
# 3     Perum. Green Garden \n Blok A.7 No.33-34 \n Ja...
# 4     Ruko Taman Kedoya Permai \n Blok A 1A No.4-5, ...
# ...                                                 ...
# 1082                        Jl.Budi Utomo, Timika 99910
# 1083  Komp. Pertokoan Jayapura Pasific Permai Blok C...
# 1084  Jln. Raya Abepura Kel. VIM Abepura-Jayapura, J...
# 1085       Jln.Trikora Wosi – Manokwari, Jayapura 98212
# 1086                      Jln. Ahmad Yani, Sorong 98416
#
# [1087 rows x 4 columns]

# %%
for q in range(len(td)):
        if len(td[q].text.split()) <= 2 :
            continue
        elif len(td[q].text.split('&')) == 2 :
            raw_td.append(td[q])
        elif td[q].text.split()[0].upper() == 'BANK' or td[q].text.split()[0].upper() == 'KANTOR':
            continue
        elif len(td[q].text.split()[0].split('-')) == 2 or len(td[q].text.split()[0].split('-')) == 3:
            continue
        else :
            raw_td.append(td[q])
# Out:
# <td width='"27%'>KCP Cimindi</td>

# %%
tr = tabs[0].find_all('tr')
td = tr[1].find_all('td')

#tabs[0]
len(kota)
# Out:
# 391

# %%
provinsi = []
kota = []

cabang = []
alamat = []

print('Scraping ', label, ' has started')

for x in range(len(tab)) :
    col = tab[0]
    prov = col.find_all('h4')
    row = col.find_all('ul')
    for y in range(len(prov)) :
        prov_temp = prov[y].text.strip('\xa0')
        #provinsi.append(prov[y].text.strip('\xa0'))
        a = row[y].find_all('a')
        for b in range(len(a)):
            kota_temp = a[b].text
            time.sleep(10)
            url = a[b]['href']
            
            response = urllib.request.urlopen(url)
            webContent = response.read().decode('UTF-8')
            link_kc = bs(webContent,'html.parser')
            
            '''if len(link_kc.find_all(class_='responsive-tabs')) == 0 :
                tabs = link_kc.find_all(class_='entry-content')
            else : 
                tabs = link_kc.find_all(class_='responsive-tabs')'''
            
            tabs = link_kc.find_all(class_='entry-content')
            for z in range(len(tabs)):
                tr = tabs[z].find_all('tr')
                for q in range(len(tr)) :
                    td = tr[q].find_all('td')
                    if len(td) == 0 or len(td)==1 :
                        continue
                    else :
                        kota.append(kota_temp)
                        provinsi.append(prov_temp)
                        cabang.append(td[1].text)
                        alamat.append(td[2].text)
                        print('Kota :', kota[-1], end='\r')

                    '''
                                td = table[z].find_all('td')
                                raw_td = []
                                if td[0].text == 'NO' or td[0].text == 'NO.' : 
                                    td = td[4:]
                                for q in range(len(td)):
                                    if td[q].text == '\xa0' or len(td[q].text) == 0:
                                        continue
                                    elif td[q].text.split()[0] in idx :
                                        raw_td.append(td[q])
                                    elif len(td[q].text.split()) <= 2 :
                                        continue
                                    elif len(td[q].text.split('&')) == 2 :
                                        raw_td.append(td[q])
                                    elif td[q].text.split()[0].upper() == 'BANK' or td[q].text.split()[0].upper() == 'KANTOR':
                                        continue
                                    elif len(td[q].text.split()[0].split('-')) == 2 or len(td[q].text.split()[0].split('-')) == 3:
                                        continue
                                    else :
                                        raw_td.append(td[q])
                                    '''
                    #break
                #break
            #break
        break
    break

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import urllib.request, urllib.error, urllib.parse
import time

url = 'https://www.alamatbank.com/alamat-kantor-bank-mandiri-di-seluruh-indonesia/'

label = 'Bank Mandiri'
resp = requests.get(url)
html = resp.content
soup = bs(html, 'html.parser')
tab = soup.find_all(class_='tabcontent')

provinsi = []
kota = []

cabang = []
alamat = []

print('Scraping ', label, ' has started')

for x in range(len(tab)) :
    col = tab[x]
    prov = col.find_all('h4')
    row = col.find_all('ul')
    for y in range(len(prov)) :
        prov_temp = prov[y].text.strip('\xa0')
        #provinsi.append(prov[y].text.strip('\xa0'))
        a = row[y].find_all('a')
        for b in range(len(a)):
            kota_temp = a[b].text
            time.sleep(10)
            url = a[b]['href']
            
            response = urllib.request.urlopen(url)
            webContent = response.read().decode('UTF-8')
            link_kc = bs(webContent,'html.parser')
            
            '''if len(link_kc.find_all(class_='responsive-tabs')) == 0 :
                tabs = link_kc.find_all(class_='entry-content')
            else : 
                tabs = link_kc.find_all(class_='responsive-tabs')'''
            
            tabs = link_kc.find_all(class_='entry-content')
            for z in range(len(tabs)):
                tr = tabs[z].find_all('tr')
                for q in range(len(tr)) :
                    td = tr[q].find_all('td')
                    if len(td) == 0 or len(td)==1 :
                        continue
                    else :
                        kota.append(kota_temp)
                        provinsi.append(prov_temp)
                        cabang.append(td[1].text)
                        alamat.append(td[2].text)
                        print('Kota :', kota[-1], end='\r')
                        #print('Provinsi :', provinsi[-1], end='\r')

                    #break
                #break
            #break
        #break
    #break

dataframe = pd.DataFrame(columns = ['City','Provinsi','Cabang','Alamat'])
dataframe['City'] = kota
dataframe['Provinsi'] = provinsi
dataframe['Cabang'] = cabang
dataframe['Alamat'] = alamat
dataframe = dataframe.loc[dataframe['Cabang'] != 'Cabang']

cabang_fix = []
for i in range(len(dataframe['Cabang'])) :
    cabang_fix.append(dataframe['Cabang'].str.split('(')[i][0].strip())
dataframe['Cabang'] = cabang_fix

alamat_fix = []
for i in range(len(dataframe['Alamat'])) :
    alamat_fix.append(dataframe['Alamat'][i].replace('\n', ''))

dataframe['Alamat'] = alamat_fix

#dataframe

dataframe.to_csv(label+'.csv', index=False)
dataframe.to_excel(label+'.xlsx', index=False)

print('Scraping '+label+' has finished')
# Out:
# Scraping  Bank Mandiri  has started
# Kota : KamparliswegghnTimur )
# Kota : Kampar
# Scraping Bank Mandiri has finished

# %%
#tabs[0]
#table = tabs[q].find_all('table')
#table[1]
#td[3].text.split()

alamat_fix = []
for u in range(len(dataframe['Alamat'])) :
    alamat_temp = dataframe['Alamat'].str.split('\n')[u]
    if len(alamat_temp) == 2 :
        alamat_fix.append(alamat_temp[0] + alamat_temp[1])
    else :
        alamat_fix.append(alamat_temp)

type(alamat_fix)
# Out:
# list

# %%
data = dataframe.loc[dataframe['Cabang'] != 'Cabang']
data.to_csv(label+'.csv', index=False)
data.to_excel(label+'.xlsx', index=False)

# %%
alamat
# Out:
# ['Jl. Daan Mogot  Jakarta Barat, JK',
#  'Komplek Perumahan dan Perkantoran  Green Ville Real Estate Blok BG No. 31-36\xa0 Jakarta Barat, JK',
#  'Jl. Lapangan Stasiun No. 2\xa0 Jakarta Barat, JK',
#  'Jl. Kyai Tapa No. 99\xa0 Jakarta Barat, JK',
#  'Komplek Puri Botanical Blok H7 No.3,  Jl. Raya Joglo  Jakarta Barat, JK',
#  'Jl. Peta Selatan No. 6 A-B,  Kalideres\xa0 Jakarta Barat, JK',
#  'Pertokoan Daan Mogot Baru,  Jl. Jimbaran Blok 7 B No. 14\xa0 Jakarta Barat, JK',
#  'Jl. Taman Anggrek  Kemanggisan Jaya\xa0 Jakarta Barat, JK',
#  'Ruko Glodok Plaza Blok H No.45-46,  Jl. Pinangsia Raya\xa0 Jakarta Barat, JK',
#  'Pasar Glodok Lt. 2 A.LO2 BKS039,\xa0 Jakarta Barat, JK',
#  'Jl. Dr. Muwardi II No. 15 A,  Grogol, Petamburan\xa0 Jakarta Barat, JK',
#  'Jl. Panjang No. 5 A,  Kebon Jeruk\xa0 Jakarta Barat, JK',
#  'Jl. Pangeran Tubagus Angke No. 10\xa0 Jakarta Barat, JK',
#  'Graha Irama Lantai Dasar  Jl. H.R. Rasuna Said Kav. X-1, No. 1-2\xa0 Jakarta Selatan, JK',
#  'Graha Iskandarsyah,  Jl. Iskandarsyah Raya No. 66\xa0 Jakarta Selatan, JK',
#  'Jl. Jend. Gatot Subroto Kav. 36-38\xa0 Jakarta Selatan, JK',
#  'Jl. Cikini Raya No. 56  Jakarta Pusat, JK',
#  'Jl. Ir. H. Juanda No. 18\xa0 Jakarta Pusat, JK',
#  'Jl. Imam Bonjol No. 61\xa0 Jakarta Pusat, JK',
#  'Jl. Tanah Abang Timur No. 1-2\xa0 Jakarta Pusat, JK',
#  'Jl. Kebon Sirih No. 83\xa0 Jakarta Pusat, JK',
#  'Jl. Jend. Ahmad Yani No. 2\xa0Jakarta Pusat, JK',
#  'Kantor Pusat PT MNA, Jl. Angkasa Blok B-15 Kav. 2-3\xa0Jakarta Pusat, JK',
#  'Ruko Segitiga Senen Blok E-21/22, Jl. Senen Raya No. 135\xa0Jakarta Pusat, JK',
#  'Jl. Bendungan Hilir Raya No. 82\xa0Jakarta Pusat, JK',
#  'Jl. Jend. Sudirman Kav. 32-33\xa0Jakarta Pusat, JK',
#  'Kompleks Pertokoan Graha Cempaka Mas Blok A 24-25, Jl. Letjend. Suprapto\xa0Jakarta Pusat, JK',
#  'Cempaka Putih Permai Blok A No. 20-21, Jl. Letjend. Suprapto\xa0Jakarta Pusat, JK',
#  'Jl. Cideng Barat No. 87\xa0Jakarta Pusat, JK',
#  'Jl. Ki S. Mangunsarkoro No. 49\xa0Jakarta Pusat, JK',
#  'Jl. Cut Meutiah No. 16\xa0Jakarta Pusat, JK',
#  'Jl. Lapangan Banteng No. 3-4\xa0Jakarta Pusat, JK',
#  'Jl. Merdeka Barat No. 13-14\xa0Jakarta Pusat, JK',
#  'Gedung 16 Lantai Departemen Keuangan, Jl.Lapangan Banteng Timur No. 2-4\xa0Jakarta Pusat, JK',
#  'Jl. Jend. Gatot Subroto Kav. 53-54\xa0Jakarta Pusat, JK',
#  'Gedung MPR/DPR RI Senayan, Jl. Jend. Gatot Subroto\xa0Jakarta Pusat, JK',
#  'Komplek Pertokoan Duta Merlin, Blok A/26-28, Jl. Gajah Mada No. 3-5\xa0Jakarta Pusat, JK',
#  'Jl. K.H. Fakhrudin No.15, Tanah Abang\xa0Jakarta Pusat, JK',
#  'Gedung Bimantara, Jl. Kebun Sirih 17-19\xa0Jakarta Pusat, JK',
#  'Jl. Merdeka Barat No. 17\xa0Jakarta Pusat, JK',
#  'Jl. Medan Merdeka Barat No. 21\xa0Jakarta Pusat, JK',
#  'Jl. M.H. Thamrin No. 12\xa0Jakarta Pusat, JK',
#  'Jl. Gajah Mada No. 14\xa0Jakarta Pusat, JK',
#  'Jl. Jend. Gatot Subroto, Manggala Wanabakti\xa0Jakarta Pusat, JK',
#  'Jl. Tanah Abang II No. 57\xa0Jakarta Pusat, JK',
#  'Jl. Industri No. 1\xa0Jakarta Pusat, JK',
#  'Ruko Permata Majalaya Blok A 6  Jl. Tengah Majalaya  Kab. Bandung, JB',
#  'Jl. Raya Dangdeur No. 137  Rancaekek  Kab. Bandung, JB',
#  'Jl. Raya Soreang No. 457  Soreang  Kab. Bandung',
#  'Komplek Taman Kopo Indah II  Ruko IB No. 19  Kab. Bandung, JB',
#  'Jl. Jend. Ahmad Yani No. 317  Cibeunying, Cimenyan Kab. Bandung, JB',
#  'Alamat',
#  'Jl. Raya Grand Hotel No. 42  Lembang  Bandung Barat, JB',
#  'Jl. Cihampelas No. 182  Cihampelas  Bandung Barat, JB',
#  'Alamat',
#  'Pertokoan Naga Swalayan Blok A 17, Jl. Sultan Agung',
#  'Ruko Sentra Niaga Blok SN 07, Jl. Boulevard Hijau, Komplek Perumahan Harapan Indah',
#  'Ruko Taman Harapan Baru Blok A 1 No.70,Kec.Medan Satria',
#  'Jl. Ir. H. Juanda No. 155',
#  'Ruko Roxy Blok E No. 1, Jl. M.H. Thamrin, Lippo Cikarang',
#  'Ruko Juanda Elok No. 3A, Jl. Ir. H. Juanda',
#  'Ruko Roxy Blok B No. 3, Jl. Kasuari Raya, Cikarang Utara',
#  'Komplek Ruko Grand Mal Bekasi Kaveling B No. 7, Jl. Raya Sudirman',
#  'Ruko Kalimas, Jl. Chairil Anwar Blok C No. 3A',
#  'Kawasan Industri MM 2100, Cibitung, Bekasi Fajar',
#  'Ruko Sentra Cikarang Blok C No.2, Jl. Raya Cikarang-Cibarusah',
#  'Ruko Commercial Center Jl. Jababeka Raya Blok B7 dan B21 Kawasan Industri Cikarang Jababeka',
#  'Naga Swalayan, Jl. Raya Hasanudin Km.38, Tambun',
#  'Komplek Perumahan Grand Wisata, Ruko Celebration Boulevard Blok AA 9 Kav.32,Tambun',
#  'Jl. Raya Perjuangan Kav. M No. 14',
#  'Jl. Kapten Sumantri No. 27, Cikarang',
#  'Ruko Kawu Jaya, Jl. Raya Pramuka No.1-2, Rawalumbu',
#  'Ruko Capitol Business Park Jl. Niaga Raya Blok 2 C, Jababeka, Cikarang',
#  'Komp. Ruko Palais de Paris Blok D-18 Cikarang Pusat',
#  'Jl. Raya Serang Cibarusah No.4 Depan Pasar Cibarusah, Kp Serang Kota, Cikarang Selatan',
#  'Komplek Ruko Perumahan Panorama Bekasi No. R 15 Jl. Kaliabang Kp. Nangka Kel. Perwira. Bekasi Utara',
#  'Jl. Raya Jatiwaringin No. 363, Pondok Gede',
#  'Jl. Jend. Ahmad Yani, Sentra Niaga Kalimalang Blok A3 No. 6-7',
#  'Jl. Jend. Ahmad Yani, Sentra Niaga Kalimalang Blok A3 No. 6-7',
#  'Jl. Jend. Ahmad Yani, Pusat Perdagangan Kalimalang Blok A VIII No.17-18',
#  'Ruko Kemang Pratama, Jl. Kemang Pratama Raya Blok MM-02',
#  'Jl. Raya Pondok Gede No. 50 B, Pondok Gede',
#  'Komplek Pertokoan Taman Galaxi, Jl. Galaxi Raya Blok G No. 1',
#  'Jl. Pulo Ribung Raya Blok AR No. 25',
#  'Pertokoan Duta Permai Blok B 1 No.10,Jl. KH Noer Ali, Kalimalang',
#  'Rukan Villa Jatibening Toll Kaveling No.A-05, Jl. Caman Raya, Jatibening, P. Gede',
#  'Jl. Raya Jati Makmur No. 53 B, Pondok Gede',
#  'Jl. Raya jati Asih No. 26',
#  'Ruko Bekasi Mas Blok E 1-2, Jl. Jend. Ahmad Yani',
#  'Komplek Citra Grand Ruko 2 No. 15, Jl. Alternatif Km.4, Pondok Gede',
#  'Jl. Raya Hankam No. 18 B-C, Jati Murni, Pondok Gede',
#  'Jl. Raya Alternatif Cibubur-Cileungsi No. 37 G, Jatisampurna',
#  'Jl. Bintara Raya No.66 RT.06 RW.01 Bekasi Barat',
#  'Jl. Raya Narogong Km.11 No. 2 A (samping pasar Bantar Gebang) Bantar Gebang',
#  'Alamat',
#  'Komplek Perumahan Villa Nusa Indah II Blok U3 No.3-4',
#  'Ruko Mall Cileungsi Blok C No. 5 & 6, Jl. Raya Narogong, Cileungsi',
#  'Ruko Sentra Eropa Blok A No.6, Perumahan Kota Wisata, Jl. Transyogie Km.6, Cibubur',
#  'Jl. Mayor Oking No. 10 – 11, Citeureup',
#  'Jl. Ir. H, Juanda No. 12',
#  'Jl. Ir. H, Juanda No. 12',
#  'Jl. Kapten Muslihat No. 17',
#  'Jl. Suryakencana No. 310',
#  'Komp. Ruko Graha Cibinong No. B-1, Jl. Raya Jakarta Bogor Km.43, Cibinong',
#  'Jl. Raya Pajajaran No. 1 – B',
#  'Jl. Raya Tajur No. 130',
#  'Ruko Bantar Kemang No.20 Q, Jl. Raya Pajajaran',
#  'Ruko Central Blok C No. 15, Jl. Dewi Sartika',
#  'Jl. Raya Simpang Pomad Ruko No. 323 C, Ciluar',
#  'Komplek Pertokoan 24, Jl. KH Soleh Iskandar No. 2 H',
#  'Gd A.H. Nasoetion Lt. Dasar Jl. Kampus IPB Darmaga',
#  'Alamat',
#  'Jl. Raya Cipanas Blok 11 No. 201, Pacet',
#  'Jl. Suroso No. 51',
#  'Jl. HOS Cikroaminoto No. 172',
#  'Alamat',
#  'Jl. Raya Cimahi No. 612 Cimahi, JB',
#  'Ruko Taman Pondok Mas Indah No. 4, Jl. Baros Cimahi, JB',
#  'Alamat',
#  'Jl. Yos Sudarso No. 11 Cirebon, JB',
#  'Jl. Kantor No. 4\xa0Cirebon, JB',
#  'Jl. Siliwangi No. 139\xa0Cirebon, JB',
#  'Jl. Raya Tegalwangi Km. 9 No. 58\xa0Cirebon, JB',
#  'Jl. Raya Panembahan No. 51, Plered\xa0Cirebon, JB',
#  'Jl. Margonda Raya No. 2  Depok, JB',
#  'Jl. Cinere Raya Kav. 32-33  Depok, JB',
#  'Jl. Nusantara Raya No. 25 AB  Depok, JB',
#  'Ruko Bukit Sawangan Indah Blok F2 No.1,  Jl.Raya Parung Km.35, Sawangan  Depok, JB',
#  'Jl. Cenere Raya No. 18 B,  Cinere  Depok, JB',
#  'Jl. Raya Bogor Km.31 No.8,  Cisalak  Depok, JB',
#  'Pertokoan ITC Depok No.49,  Jl. Margonda Raya  Depok, JB',
#  'Jl. Raya Tole Iskandar No. 1  Depok, JB',
#  'Pertokoan Kartini Blok A No. 11,  Jl. Kartini Raya,  Pancoran Mas  Depok, JB',
#  'Jl. Raya Akses UI No. 88 C,  Kelapa Dua,  Cimanggis  Depok, JB',
#  'Jl. Raya Margonda No. 345 D,  Pondok Cina  Depok, JB',
#  'Komplek Ruko Sukmajaya No. 15,  Jl. Tole Iskandar,  Depok II Tengah  Depok, JB',
#  'Jl. Proklamasi Raya Blok A No.7-8,  Depok II Timur  Depok, JB',
#  'Kompk. Kantor PLN (Persero) UBS P3B,  Jl. Garuda No. 15  Depok, JB',
#  'Kampus Universitas Indonesia,  Gedung Pascasarjana Fakultas Ekonomi  Depok, JB',
#  'Jl. Margonda Raya No. 2  Depok, JB',
#  'Alamat',
#  'Jl. Ahmad Yani No. 24',
#  'Jl. Garut Cikajang No. 99',
#  'Jl. Raya Garut-Bandung No. 4 Blok A Kel. Karangmulya',
#  'Jl. Guntur Blok A-18 (Intan Business Center A-18) Kel. Pakuwon',
#  'Alamat',
#  'Jl. D.I. Panjaitan No. 8 Indramayu, JB',
#  'Jl. Tanjungpura No. 01 Blok G-33 Karangmalang\xa0Indramayu, JB',
#  'Jl. Mayor Dasuki No. 92, Jatibarang\xa0Indramayu, JB',
#  'Jl. Raya Balongan (Depo Pertamina)\xa0Indramayu, JB',
#  'Alamat',
#  'Jl. Tuparev No. 44, Karawan, JB',
#  'Jl. Raya Duren No. 24 A, Klari, Kosambi, Karawang, JB',
#  'Alamat',
#  'Pertokoan Siliwangi No. 39-40, Jl. Siliwangi, Kuningan',
#  'Jl. Pasar Kepuh No. 47',
#  'Alamat',
#  'Jl. Raya Timur No. 124, Kadipaten',
#  'Alamat',
#  'Jl. Sudirman No. 176',
#  'Alamat',
#  'Jl. Ion Martasasmita No. 35, Pamanukan',
#  'Jl. Jenderal Ahmad Yani No.5',
#  'Jl. Raya Kalijati – Kec. Subang',
#  'Jl. Raya Jalan Cagak – Kec. Jalan Cagak',
#  'Alamat',
#  'Jl. Jend. Sudirman No. 124\xa0 Sukabumi, JB',
#  'Jl. Ahmad Yani No. 44\xa0 Sukabumi, JB',
#  'Jl. Suryakencana No. 4,  Cibadak\xa0 Sukabumi, JB',
#  'Jl. Pelabuhan II No.3 KM.12\xa0 Cikembar  Sukabumi, JB',
#  'Jl. Siliwangi No. 287 B,  Cicurug\xa0 Sukabumi, JB',
#  'Jl. Siliwangi No. 62  Pelabuhan Ratu\xa0 Sukabumi, JB',
#  'Alamat',
#  'Jl. Mayor Abdurachman No. 99',
#  'Dusun Wado Girang, RT. 03 RW. 03 Kec. Wado',
#  'Kampus Universitas Pajajaran Jl. Raya Sumedang, Jatinangor',
#  'Jalan Raya Tanjungsari No. 154 Sumedang',
#  'Alamat',
#  'Jl. Otto Iskandardinata No. 26',
#  'Jl. H.Z. Mustofa No. 294',
#  'Jl. Sutisna Senjaya No. 88',
#  'Jl. Otto Iskandardinata No. 26',
#  'Jl. RTA Prawira Adiningrat No. 59 Pasar Kaler Manonjaya',
#  'Jl. Raya Timur Singaparna No.23 Cikiray Singaparna',
#  'Alamat',
#  'Jl. S. Parman No. 31',
#  'Alamat',
#  'Jl. Jendral Gatot Subroto No. 756',
#  'Jl. Raya Pancasan No. 12, Ajibarang',
#  'Jl. Gatot Subroto No.04 . Sokaraja',
#  'Alamat',
#  'Jl. Jend. Sudirman No. 323 – Batang',
#  'Alamat',
#  'Jl. Alun-Alun Selatan No. 5',
#  'Alamat',
#  'Jl. Raya Karanggede, Sruwen – Karanggede',
#  'Jl. Kates, Pulian',
#  'Alamat',
#  'Plaza Dedy Jaya, Jl. Jenderal Sudirman No. 109',
#  'Jl. Jend. Sudirman Ketanggungan',
#  'Alamat',
#  'Jl. Jend. Ahmad Yani No. 100 Cilacap, JT',
#  'Komplek Pertamina Depot Maos Jl. Pertamina Maos Kidul\xa0Cilacap, JT',
#  'Jl. Diponegoro No. 85 Majenang\xa0Cilacap, JT',
#  'Alamat',
#  'Jl. Sultan Fatah No. 4B',
#  'Alamat',
#  'Jl. MT Haryono No. 1, Gubug',
#  'Alamat',
#  'Jl. HOS Cokroaminoto No. 4',
#  'Alamat',
#  'Jl. Raya Palur No. 32, Jaten',
#  'Jl. Lawu No. 386',
#  'Jl. Lawu No. 85 Karangpandan',
#  'Alamat',
#  'Jl. Pahlawan No. 126',
#  'Alamat',
#  'Jl. Sukarno Hatta No. 278',
#  'Jl. Raya Bebengan No. 256, Boja',
#  'Jl. Terminal No. 3, Komplek Pertokoan Faulia Kios No.2 Sukorejo',
#  'Alamat',
#  'Jl. Pemuda Selatan No. 121, Tonggalan',
#  'Jl. Raya Pasar Pedan RT. 02/10 Kios No 7, Sobayan',
#  'Jl. Raya No. 3B Prambanan',
#  'Alamat',
#  'Jl. Jend. Ahmad Yani No. 10 A',
#  'Alamat',
#  'Jl. Jend. Sudirman No. 164 Kudus, JT',
#  'Jl. Jenderal Sudirman No. 3 C Kudus, JT',
#  'Alamat',
#  'Jl. Sudirman No. 26, Komplek Pertokoan Rejotumoto',
#  'Jl. Ahmad Yani No. 203',
#  'Jl. Raya Purworejo Km 5',
#  'Alamat',
#  'Kompleks Ruko Muntilan Plaza Jl. Pemuda',
#  'Alamat',
#  'Jl. Kol. Kusnandar Komplek Ruko Pasar Puri Blok 6-7',
#  'Jl. Panglima Sudirman No. 32 – 33 Juwana',
#  'Alamat',
#  'Jl. Gatot Subroto No. 87 Randudongkal, Pemalang',
#  'Jl. Ahmad Yani Ruko Blok A No.10 Comal',
#  'Jl. Sudirman No. 59',
#  'Alamat',
#  'Jl. Imam Bonjol No. 34',
#  'Jl. Hayam Wuruk No. 5',
#  'Jl. Alun-alun No. 3',
#  'Alamat',
#  'Jl. Brigjen. Suwondo No. 9, Kec. Bobotsari',
#  'Jl. Jenderal Sudirman No. 37',
#  'Alamat',
#  'Jl. Kol. Sugiono No. 5',
#  'Alamat',
#  'Jl. Kol. Sugiono No. 5',
#  'Alamat',
#  'Jl. Diponegoro No. 36',
#  'Jl. Pahlawan No. 3,  Semarang, JT',
#  'Jl. Pemuda No. 73  Semarang, JT',
#  'Komp. Bangkong Plaza B 4-6  Jl. M.T. Haryono No. 864-866,  Semarang, JT',
#  'Ruko Sultan Agung  Jl. S. Parman No. 55 K,  Semarang, JT',
#  'Jl. Gang Pinggir No. 13 A  Semarang, JT',
#  'Gedung PT Telkom (Persero),  Jl. Pahlawan No. 10  Semarang, JT',
#  'Kawasan Industri Candi,  Jl. Candi Raya Blok F1E No.1-2  Semarang, JT',
#  'Jl. Kepodang No. 32-34  Semarang, JT',
#  'Kompleks Ruko Majapahit,  Jl. Majapahit No. 339  Semarang, JT',
#  'Jl. Mpu Tantular No. 19  Semarang, JT',
#  'Jl. M.T. Haryono No. 419  Semarang, JT',
#  'Ruko C,D,E  Jl. Prof. Dr. Hamka No. 9  Tugu  Semarang, JT',
#  'Jl. Pandanaran No. 104  Semarang, JT',
#  'Jl. Dr. Sutomo No. 16  Semarang, JT',
#  'Jl. Setiabudi No. G 62 E & F  Semarang, JT',
#  'Jl. Mgr. Sugiyopranoto No. 36 A-B  Semarang, JT',
#  'Jl. Prof. Dr. Sudharto No. 9 B,  Tembalang  Semarang, JT',
#  'Jl. Sisingamangaraja  Semarang, JT',
#  'Komp. Pelabuhan Tanjung Emas,  Jl. Coaster No. 10  Semarang, JT',
#  'Jl. Pemuda No. 73  Semarang, JT',
#  'Jl. Jenderal Sudirman No.122,  Ambarawa  Kab. Semarang, JT',
#  'Jl. Gintungan No. 3,  Bandungan,  Kab. Semarang, JT',
#  'Jl. Diponegoro Bringin, RT.06/01,  Desa Bringin  Kab. Semarang, JT',
#  'Jl. Jend. Gatot Subroto No. 671 E-F,  Ungaran  Kab. Semarang, JT',
#  'Alamat',
#  'Plaza Atrium Blokc C-D, Jl. Raya Sukowati No. 302-304',
#  'Jl. Diponegoro No. 3 Gemolong',
#  'Alamat',
#  'RSO Prof.Dr.Soeharso,Jl. Jenderal Ahmad Yani, Pabelan',
#  'Jl. Ahmad Yani No. 98',
#  'Jl. Jenderal Sudirman No. 29',
#  'Alamat',
#  'Jl. Brigjend. Slamet Riyadi No. 294  Surakarta, JT',
#  'Jl. Brigjend. Slamet Riyadi No. 329  Surakarta, JT',
#  'Jl. Brigjend. Slamet Riyadi No. 16  Surakarta, JT',
#  'Komplek Pasar Klewer Los E 27-29,  Jl. Dr. Rajiman  Surakarta, JT',
#  'Jl. Yos Sudarso No. 387  Surakarta, JT',
#  'Pasar Legi  Jl. Sutan Syahrir No. 204  Surakarta, JT',
#  'Jl. Brigjend. Slamet Riyadi No. 294  Surakarta, JT',
#  'Alamat',
#  'Jl. Arief Rahman Hakim No. 19',
#  'Jl. Jend. Sudirman No. 11',
#  'Jl. Raya Banjaran No. 10, Adiwerna',
#  'Alamat',
#  'Jl. Tentara Pelajar No. 1',
#  'Jl. Pahlawan No. 28, Parakan',
#  'Alamat',
#  'Jl. Jenderal Sudirman No. 132',
#  'Jl. Wonogiri Pacitan, Baturetno',
#  'Alamat',
#  'Jl. Sumbing No. 18',
#  'Alamat',
#  'Jl. Soekarno Hatta No. 17 B',
#  'Alamat',
#  'Jl. Raya Jajag No.57',
#  'Jl. Dr. Wahidin Sudiro Husodo No. 2',
#  'Jl. Gajah Mada No. 253, Genteng',
#  'Jl. Raya Rogojampi No. 12-14, Rogojampi',
#  'Jl. Brawijaya No. 115 Muncar',
#  'Jl. Raya Grajagan No.9 Purwoharjo, Banyuwangi',
#  'Jl. Dewi Sartika No. 45,  Batu, JI',
#  'Alamat',
#  'Jl. Merdeka No. 30',
#  'Jl. Urip Sumoharjo No.105 Wlingi, Blitar',
#  'Alamat',
#  'Jl. Teuku Umar No. 47 B',
#  'Jl. Raya Sumberrejo RT 025 RW 08 Sumberrejo',
#  'Alamat',
#  'Jl. Ki S. Mangunsarkoro No. 69 Tamansari',
#  'Jl. R.A. Kartini No. 210  Gresik, JI',
#  'Jl. Sukomulyo No. 10,  Manyar\xa0 Gresik, JI',
#  'Jl. Veteran\xa0 Gresik, JI',
#  'Gedung Graha Sarana Gresik  Jl. A. Yani\xa0 Gresik, JI',
#  'Alamat',
#  'Jl. Merdeka No. 115',
#  'Alamat',
#  'Jl. Diponegoro No. 17 Kediri, JI',
#  'Jl. Joyoboyo No. 34 A\xa0Kediri, JI',
#  'Jl. Panglima Besar Sudirman No. 43, Pare\xa0Kediri, JI',
#  'Alamat',
#  'Jl. Raya Babat No.270 Babat',
#  'Jl. Raya Brondong RT 001 RW 003 Brondong',
#  'Alamat',
#  'Jl. Lamongrejo No. 120',
#  'Alamat',
#  'Jl. Panglima Sudirman No. 33',
#  'Jl. Raya Pasirian No. 180, Lumajang',
#  'Alamat',
#  'Jl. Pahlawan No. 29',
#  'Jl. Panglima Sudirman No. 38',
#  'Jl. K.H. Wahid Hasyim No. 5-7,  Malang, JI',
#  'Jl. Jend. Ahmad Yani No. 50 C-D,  Malang, JI',
#  'Jl. Jend. Gatot Subroto No. 9 A,  Malang, JI',
#  'Ruko Griya Shanta Blok MP-53,  Jl. Soekarno – Hatta,  Malang, JI',
#  'Jl. Merdeka Barat No. 1,  Malang, JI',
#  'Jl. MT Haryono No. 131,  Malang, JI',
#  'Jl. Danau Toba No. E6/25,  Malang, JI',
#  'Jl. Jaksa Agung Suprapto 65,  Malang, JI',
#  'Kampus Universitas Brawijaya,  Jl. Veteran,  Malang, JI',
#  'Jl. Merdeka Barat No. 1,  Malang, JI',
#  'Jl. Semeru Selatan No. 9,  Dampit,  Kab. Malang, JI',
#  'Jl. Ahmad Yani No. 5,  Kepanjen,  Kab. Malang, JI',
#  'Ruko Istana Lawang Blok A5,  Jl. Dr. Soetomo,  Lawang,  Kab. Malang, JI',
#  'Alamat',
#  'Jl. Mojopahit No. 406',
#  'Jl. Hayam Wuruk No. 35 C, Mojosari',
#  'Alamat',
#  'Jl. Raya Ahmad Yani No. 207',
#  'Jl. Gatot Subroto No.10, Kertosono',
#  'Alamat',
#  'Jl. Jaksa Agung Suprapto No.35',
#  'Alamat',
#  'Jl. Pangeran Diponegoro No.151',
#  'Alamat',
#  'Jl. Panglima Sudirman No. 11',
#  'Alamat',
#  'Jl. Urip Sumoharjo No. 102',
#  'Alamat',
#  'Jl. Suroyo No. 23',
#  'Jl. Panglima Sudirman No. 119, Kraksaan',
#  'Jl. Raya Maron No. 722 Maron Probolinggo',
#  'Alamat',
#  'Jl. Tronojoyo No. 50',
#  'Alamat',
#  'Jl. Ahmad Yani No. 7\xa0Sidoarjo, JI',
#  'Jl. Raya Candi No. 42\xa0 Sidoarjo, JI',
#  'Ruko Gateway Blok C-7  Waru\xa0 Sidoarjo, JI',
#  'Jl. Raya Krian No. 47  Krian\xa0 Sidoarjo, JI',
#  'Ruko Pondok Mutiara Indah Blok N-02  Jl. Pahlawan\xa0 Sidoarjo, JI',
#  'Jl. Bebekan No. 23  Sepanjang\xa0 Sidoarjo, JI',
#  'Alamat',
#  'Jl. Jend. Ahmad Yani No. 102',
#  'Jl. Niaga No. 65, Besuki Situbondo',
#  'Alamat',
#  'Jl. Raya Trunojoyo No. 55 Sumenep, JI',
#  'Alamat',
#  'Jl. Basuki Rahmat No. 129-137  Surabaya',
#  'Jl. Gentengkali No. 93-95  Surabaya',
#  'Jl. Veteran No. 42-44  Surabaya',
#  'Jl. Ngagek Jaya Selatan,  Plaza Manyar Megah Indah Blok J 5-6  Surabaya',
#  'Perumahan Citra Raya Gwalk Blok W-1 No.10-11  Surabaya',
#  'Komplek Ruko Darmo Indah Timur,  Jl. Darmo Indah Timur Blok SS No.8  Surabaya',
#  'Komplek Pertokoan Darmo Park I Blok V No.5-6,  Jl. Mayjend. Sungkono  Surabaya',
#  'Jl. H.R. Muhammad 36, Ruko Permata Blok B-1 Surabaya',
#  'Jl. Raya Darmo No. 41  Surabaya',
#  'Jl. Raya Diponegoro No. 155  Surabaya',
#  'Jl. Kalimantan No.10  Surabaya',
#  'Jl. Indragiri No.30-32  Surabaya',
#  'Jl. Indrapura No. 45  Surabaya',
#  'Jl. Jembatan Merah No. 25-27  Surabaya',
#  'Jl. Jemursari No. 81  Surabaya',
#  'Jl. Kapas Krampung No.67 Kav. 06  Surabaya',
#  'Jl. Kapasan No. 159  Surabaya',
#  'Jl. Kedungdoro No. 84  Surabaya',
#  'Jl. Kembang Jepun No.168-170  Surabaya',
#  'Ruko Kenjeran Indah,  Jl. Babatan Pantai No. 2 AB  Surabaya',
#  'Jl. Dharmahusada Indah No. 130  Surabaya',
#  'Jl. Klampis Jaya No. 50  Surabaya',
#  'Jl. Kupang Jaya A I No. 43',
#  'Jl. Kusuma Bangsa No. 106  Surabaya',
#  'Jl. Raya Margorejo Indah Kav. A No. 131 – 132  Surabaya',
#  'Jl. A. Yani Komplek Menanggal B1-B3  Surabaya',
#  'Jl. Raya Mulyosari No. 360 D-E  Surabaya',
#  'Jl. Pahlawan No. 120  Surabaya',
#  'Jl. Raya Bukit Darmo Boulevard No.8 G  Surabaya',
#  'Pusat Perbelanjaan Pasar Atum Mall Lantai 2, Stand No. BA 25-29, Jl. Stasiun Kota',
#  'Kompleks Pertokoan Dupak Megah Blok B-6,  Jl. Dupak No. 3-9  Surabaya',
#  'Jl. Prof. Dr. Moestopo No. 2  Surabaya',
#  'Jl. Perak Timur No.512 Blok H3-H4  Surabaya',
#  'Jl. Pemuda No. 27-31  Surabaya',
#  'Jl. Pucang Anom Timur No. 12  Surabaya',
#  'Jl. Rungkut Industri Raya No. 10',
#  'Komp. Ruko Rungkut Mutiara B-02, Jl. Raya Rungkut Madya',
#  'Komplek Pertokoan Rungkut Megah Raya Blok E/5-6,  Jl. Raya Kali Rungkut No.5  Surabaya',
#  'Jl. Stasiun Kota No.60 C-D Kav. No.1 dan 2  Surabaya',
#  'Jl. Mayjend. Sungkono No. 121 F  Surabaya',
#  'Jl. Perak Timur No. 398  Surabaya',
#  'Jl. Basuki Rahmat No. 2-4  Surabaya',
#  'Jl. Undaan Kulon No. 105 A  Surabaya',
#  'Komplek Ruko Taman Pondok Indah Kav.A-35,  Jl. Raya Menganti No. 207, Wiyung  Surabaya',
#  'Jl. Basuki Rahmat No. 129-137',
#  'Jl. H.R. Muhammad 36, Ruko Permata Blok B-1  Surabaya',
#  'Jl. Dharmahusada Indah No. 130  Surabaya',
#  'Markas Komando TNI AL, Gedung Panti Tjahaya Armada, Basis TNI AL Ujung  Surabaya',
#  'Darmo Trade Center Lt. 1 Kios A1-2,  Jl. Wonokromo Raya Surabaya',
#  'Jl. Kayun No. 72',
#  'Jl. Jagir, Wonokromo  Surabaya',
#  'Kantor Pusat PT. PAL Tanjung Perak Surabaya',
#  'Jl. Kalibutuh No. 215',
#  'Jl. Ketintang No. 156  Surabaya',
#  'Jl. Dinoyo No. 41-44  Surabaya',
#  'Kampus B, Universitas Airlangga, Jl. Airlangga No. 4-6',
#  'Jl. Siwalankerto No. 121-131  Surabaya',
#  'Alamat',
#  'Jl. Basuki Rachmat No. 75 Tuban JI',
#  'Gedung Domitory Semen Gresik Tuban Sumberarum Tuban JI',
#  'Alamat',
#  'Jl. Panglima Sudirman',
#  'Alamat',
#  'Jl. Sudirman No. 55',
#  'Komplek Ruko Jalan Raya II, Kec. Ngunut',
#  'Alamat',
#  'Jl. Sudirman No. 18',
#  'Alamat',
#  'Jl. Air Kuang No. 2, Parit Tiga, Kec.Jebus',
#  'Alamat',
#  'Jl. Jenderal Sudirman No. 414, Manggar',
#  'Alamat',
#  'Jl. Yos Sudarso No. 1 / 78',
#  'Alamat',
#  'Jl. Jend. Sudirman No. 7',
#  'Jl. Depati Amir No 45 A (d/h Jl. Mentok)',
#  'Alamat',
#  'Jl. Merdeka No. 6',
#  'Alamat',
#  'Jl. Letjend. S. Parman No. 183 Bengkulu, BE',
#  'Jl. Jend. Ahmad Yani No. 60 Bengkulu, BE',
#  'Jl. Salak Raya No. 297 B, Bengkulu, BE',
#  'Alamat',
#  'Jl. Jend. Sudirman No.231, Kel. Pasar Mulia, Kec. Pasar Manna',
#  'Alamat',
#  'Jl. Ir. Sutami, Kel. Purwodadi, Kec. Kota Arga Makmur',
#  'Alamat',
#  'Jl. Merdeka No. 225, Curup',
#  'Alamat',
#  'Jl. Gajah Mada No.9',
#  'Alamat',
#  'Jl. Lintas Sumatra Km. 1 No. 64-66',
#  'Jl Batang Hari (Jl Poros SPA) No.99 A RT 06/02 Dusun Purwosari Kec. Pelepat Ilir',
#  'Alamat',
#  'Jl. Jend. Gatot Subroto No. 60 A  Jambi, JA',
#  'Jl. Dr. Sutomo, PO BOX 14  Jambi, JA',
#  'Jl. Dr. Sam Ratulangi No. 20  Jambi, JA',
#  'Jalan Lintas Timur Km.35  Desa Sengeti  Muaro Jambi, JA',
#  'Jl. Kol. Abunjani No. 54  Jambi, JA',
#  'Jl. Prof. Dr. Sri S.M. Sofwan, SH No. 27, Telanaipura  Jambi, JA',
#  'Alamat',
#  'Jl. Poros Unit I Blok 1B No.252 Mekar Sari Makmur, Sei Bahar',
#  'Alamat',
#  'Jl Lintas Sumatera Ds. Bukit Tigo RT.01/03 No.11 Kel. Bukit Tigo, Kec Singkut',
#  'Alamat',
#  'Jl Lintas Timur Sumatera Ds Merlung No.2 Sebelah KPM Kec. Merlung',
#  'Jl.KI Hajar Dewantara No.30 Kel.Tungkal IV Kota, Tungkal Ilir',
#  'Alamat',
#  'Jl Ahmad Yani RT.19 Blok A No.8, Ds Simpang Pandan, Kec Geragai',
#  'Alamat',
#  'Jl. Pahlawan No. 86 – 88, Pasar Sarinah',
#  'Alamat',
#  'Jl. Laksamana Malahayati No. 3  Bandar Lampung, LA',
#  'Jl. Pangeran Antasari No. 149 B – C  Bandar Lampung, LA',
#  'Jl. Cut Meutiah No. 46  Bandar Lampung, LA',
#  'Jl. Yos Sudarso  Panjang  Bandar Lampung, LA',
#  'Jl. Raden Intan No. 132  Bandar Lampung, LA',
#  'Jl. W.R. Supratman No. 70  Bandar Lampung, LA',
#  'Jl. Laksamana Malahayati No. 30  Bandar Lampung, LA',
#  'Jl. Teuku Umar No. 7  Bandar Lampung, LA',
#  'Jl. Ki Maja No. 131 C,D,E  Sepang Jaya, Way Halim  Bandar Lampung, LA',
#  'Jl. W.R. Supratman No. 70  Bandar Lampung, LA',
#  'Alamat',
#  'Jl. Raya Sidomulyo (Pasar Sidomulyo) Desa Sidodadi',
#  'Jl. Raya Natar No.88 Desa Muara Putih, Kec. Natar',
#  'Alamat',
#  'Jl. Proklamator No. 33 A, Bandar Jaya',
#  'Jl.Balai Trans No.4-5 Kec.Kota Gajah Kab. Lampung Tengah',
#  'Jl. Raya Way Jepara No.278 Kec. Labuhan Ratu Lampung Timur',
#  'Alamat',
#  'Jl. Jend. Sudirman No. 39 A',
#  'Alamat',
#  'Jl. Ahmad Yani No. 18, Pringsewu',
#  'Alamat',
#  'Jl. Lintas Timur, Desa Dwi Tunggal Jaya, Banjar Agung',
#  'Alamat',
#  'Jl. Teuku H. Daud Beureuh No. 15 H  Banda Aceh, AC',
#  'Jl. Cut Meutia No. 2  Banda Aceh, AC',
#  'Gedung AAC Prof.Dr.Dayan Dawood,  Universitas Syah Kuala,  Jl. Teuku Nyak Arief  Kampus Unsyiah Darussalam  Banda Aceh, AC',
#  'Alamat',
#  'Jl. Merdeka No. 93 – Tapak Tuan',
#  'Alamat',
#  'Jl. Cut Nyak Dien No. 21 A, Kuala Simpang',
#  'Alamat',
#  'Jl. Sengeda No. 77-78, Takengon',
#  'Alamat',
#  'Jl. Iskandar Muda No. 102 ABC',
#  'Alamat',
#  ...]

# %% [raw]
# 4resp = requests.get(url)
# html = resp.content
# soup = bs(html, 'html.parser')
#
# import urllib.request, urllib.error, urllib.parse
#
# url = 'http://www.alamatbank.com/kantor-bank-bca-di-jakarta-barat/'
#
# response = urllib.request.urlopen(url)
# webContent = response.read().decode('UTF-8')
#
# print(webContent)

# %%
s = 'Bank & ATM Center Kompleks'
ss = s.split('&')
len(ss)
# Out:
# 2

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import urllib.request, urllib.error, urllib.parse
import time

url = 'https://www.alamatbank.com/alamat-kantor-bank-bca-di-seluruh-indonesia/'
resp = requests.get(url)
html = resp.content
soup = bs(html, 'html.parser')
tab = soup.find_all(class_='tabcontent')

provinsi = []
kota = []
link = []

cabang = []
alamat = []

for x in range(len(tab)) :
    col = tab[0]
    prov = col.find_all('h4')
    row = col.find_all('ul')
    for y in range(len(prov)) :
        prov_temp = prov[0].text.strip('\xa0')
        #provinsi.append(prov[y].text.strip('\xa0'))
        a = row[0].find_all('a')
        for b in range(len(a)):
            
            time.sleep(10)
            url = a[b]['href']
            
            response = urllib.request.urlopen(url)
            webContent = response.read().decode('UTF-8')
            link_kc = bs(webContent,'html.parser')
            
            '''if len(link_kc.find_all(class_='responsive-tabs')) == 0 :
                tabs = link_kc.find_all(class_='entry-content')
            else : 
                tabs = link_kc.find_all(class_='responsive-tabs')'''
            tabs = link_kc.find_all(class_='entry-content')
                   
            for q in range(len(tabs)) :
                table = tabs[q].find_all('table')
                for w in range(len(table)) :
                    td = table[w].find_all('td')
                    raw_alamat = []
                    if td[0].text == 'NO' : 
                        td = td[4:]
                    
                    for e in range(len(td)):
                        if len(td[e]) <= 1 :
                            continue
                        else :
                            raw_alamat.append(td[e])

                    for r in range(0,len(raw_alamat),2) :
                        cabang.append(raw_alamat[r])
                    for t in range(1,len(raw_alamat),2) :
                        alamat.append(raw_alamat[t])
                        kota.append(a[b].text)
                        provinsi.append(prov_temp)
                        print('Row_Count : ', len(alamat), end='\r')
                                
        #break
    #break
dataframe = pd.DataFrame(columns = ['City','Provinsi','Cabang','Alamat'])
dataframe['City'] = kota
dataframe['Provinsi'] = provinsi
dataframe['Cabang'] = cabang
dataframe['Alamat'] = alamat

dataframe
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 20>()
#      27 a = row[0].find_all('a')
#      28 for b in range(len(a)):
# ---> 30     time.sleep(10)
#      31     url = a[b]['href']
#      33     response = urllib.request.urlopen(url)
#
# KeyboardInterrupt:

# %%
h4 = tab[0].find_all('h4')
h4[0].text.strip('\xa0')


#link_kc.find_all(class_='entry-content')
if len(link_kc.find_all(class_='responsive-tabs')) == 0 :
        tabs = link_kc.find_all(class_='entry-content')
else : 
        tabs = link_kc.find_all(class_='responsive-tabs')
        
table = tabs[q].find_all('table')
td = table[w].find_all('td')
td = td[5:]
td[0].text
#raw_alamat

dataframe['Link'][0]
# Out:
# 'http://www.alamatbank.com/kantor-bank-bca-di-jakarta-barat/'

# %%
dataframe['Alamat'] = alamat

# %%
url = dataframe['Link'][4]
          
response = urllib.request.urlopen(url)
webContent = response.read().decode('UTF-8')
link_kc = bs(webContent,'html.parser')
                                    
tabs = link_kc.find_all(class_='entry-content')        
table = tabs[0].find_all('table')  
td = table[w].find_all('td')
if td[0].text == 'NO' : 
    td = td[4:]
td
# Out:
# [<td width="39">1</td>,
#  <td width="222">KCP Ancol (0211)</td>,
#  <td width="347">Jln. Parang Tritis Blok A VI No.3B-3C. Jakarta, 14430</td>,
#  <td width="183">021-6902191, 6909190</td>,
#  <td width="39">2</td>,
#  <td width="222">KCP Artha Gading (8400)</td>,
#  <td width="347">Ruko Artha Gading Blok A 15-16, Jln. Boulevar Artha Gading. Jakarta, 14240</td>,
#  <td width="183">021-45850328-30</td>,
#  <td width="39">3</td>,
#  <td width="222">KCP Boulevard Timur (6600)</td>,
#  <td width="347">Jln. Boulevard Timur Blok NC 1 No.54-55. Jakarta, 14240</td>,
#  <td width="183">021-4517131-32</td>,
#  <td width="39">4</td>,
#  <td width="222">KCP CBD Pluit (8060)</td>,
#  <td width="347">Kawasan Hunian dan Bisnis Terpadu CBD Pluit Blok B No. 9 &amp; 10, Jln. Pluit Selatan Raya. Jakarta, 14440</td>,
#  <td width="183">021-66673301</td>,
#  <td width="39">5</td>,
#  <td width="222">KCP Elang Laut (6275)</td>,
#  <td width="347">Ruko Elang Laut Boulevard, Pantai Indah Kapuk, Jl.Pantai Indah Selatan I Blok A 28 &amp; 29. Jakarta, 14460</td>,
#  <td width="183">021-56947484, 56947494-7</td>,
#  <td colspan="4" style="text-align: center;">Bank BCA di Jakarta Utara</td>,
#  <td width="39">6</td>,
#  <td width="222">KCP Gading Bukit Indah (7480)</td>,
#  <td width="347">Jln. Bukit Gading Raya Blok D/1. Jakarta, 14240</td>,
#  <td width="183">021-45840715, 4515822</td>,
#  <td width="39">7</td>,
#  <td width="222">KCP Gading Riviera (8710)</td>,
#  <td width="347">Jln. Raya Kelapa Hibrida, Ruko Gading Riviera Blok PF 21/10. Jakarta, 14250</td>,
#  <td width="183">021-45874634, 45874636</td>,
#  <td width="39">8</td>,
#  <td width="222">KCP Gading Square (8700)</td>,
#  <td width="347">Komplek Rukan Kelapa Gading Square, Jln. Boulevard Barat Raya Blok C No. 17. Jakarta, 14240</td>,
#  <td width="183">021-45866861-3</td>,
#  <td width="39">9</td>,
#  <td width="222">KCP Graha Kirana (6380)</td>,
#  <td width="347">Gedung Graha Kirana, Jl. Yos Sudarso No. 88. Jakarta, 14240</td>,
#  <td width="183">021-65311325</td>,
#  <td width="39">10</td>,
#  <td width="222">KCP Griya Utama (6460)</td>,
#  <td width="347">Ruko Puri Mutiara, Jln. Griya Utama A No. 37-38. Jakarta, 14350</td>,
#  <td width="183">021-65310876, 65310877-79</td>,
#  <td colspan="4" style="text-align: center;"><strong>Bank BCA di Jakarta Utara</strong></td>,
#  <td width="39">11</td>,
#  <td width="222">KCP Gunung Sahari (0212)</td>,
#  <td width="347">Pert.Gunung Sahari Indah Blok B/11-12, Jl.Raya Gunung Sahari 13. Jakarta, 14420</td>,
#  <td width="183">021-6459965 (hunting)</td>,
#  <td colspan="4" style="text-align: center;">Bank BCA di Jakarta Utara</td>,
#  <td width="39">12</td>,
#  <td width="222">KCP Jembatan Dua (0074)</td>,
#  <td width="347">Jln. Jembatan Dua 82 BB-BC. Jakarta, 14450</td>,
#  <td width="183">021-6604438-40</td>,
#  <td width="39">13</td>,
#  <td width="222">KCP Kapuk Kamal (0313)</td>,
#  <td width="347">Jln. Raya Kapuk Kamal No. 1A Blok DEF.Jakarta, 14470</td>,
#  <td width="183">021-6198279, 6198282</td>,
#  <td width="39">14</td>,
#  <td width="222">KCP Kapuk Muara (0408)</td>,
#  <td width="347">Komp.Duta Harapan Indah, Jln. Kapuk Muara Blok K.32-33. Jakarta, 14460</td>,
#  <td width="183">021-6606181-83</td>,
#  <td width="39">15</td>,
#  <td width="222">KCP Kelapa Gading (0227)</td>,
#  <td width="347">Jln. Kelapa Gading Boulevard Blok FX No.9-10. Jakarta, 14240</td>,
#  <td width="183">021-4524913, 4532801-02</td>,
#  <td colspan="4" style="text-align: center;">Bank BCA di Jakarta Utara</td>,
#  <td width="39">16</td>,
#  <td width="222">KCU KELAPA GADING (0065)</td>,
#  <td width="347">Menara Satu Sentra Kelapa Gading Lt. Dasar, 1, 9, dan 10, Jl. Bulevar Kelapa Gading LA3 No. 1. Jakarta, 14240</td>,
#  <td width="183">021-29385709, 29385710</td>,
#  <td width="39">17</td>,
#  <td width="222">KCP Kelapa Gading Hibrida (6300)</td>,
#  <td width="347">Jln. Bulevar Raya Blok RA-1 No. 14-15, Kelapa Gading. Jakarta, 14250</td>,
#  <td width="183">021-4516678</td>,
#  <td width="39">18</td>,
#  <td width="222">KCP Kelapa Gading Raya (6320)</td>,
#  <td width="347">Jl. Bulevard Raya Blok L No. 1 Kelapa Gading. Jakarta, 14240</td>,
#  <td width="183">021-45850123, 45850101</td>,
#  <td width="39">19</td>,
#  <td width="222">KCP Kelapa Gading Villa (0413)</td>,
#  <td width="347">Jln. Boulevard Barat Raya Blok LC No.51-52. Jakarta, 14240</td>,
#  <td width="183">021-4507890-91, 4507892-94</td>,
#  <td width="39">20</td>,
#  <td width="222">KCP Kirana Boutique (8310)</td>,
#  <td width="347">Ruko Kirana Boutique di Jl. Kirana Avenue 3 Blok E 2 No. 8-9, Kelapa Gading, Jakarta. Jakarta, 14240</td>,
#  <td width="183">021-29565201 ¿ 2</td>,
#  <td colspan="4" style="text-align: center;"><strong>Bank BCA di Jakarta Utara</strong></td>,
#  <td width="39">21</td>,
#  <td width="222">KCP Kramat Jaya (0414)</td>,
#  <td width="347">Jln. Kramat Jaya Blok F1/10. Jakarta, 14130</td>,
#  <td width="183">021-4400742 (hunting)</td>,
#  <td width="39">22</td>,
#  <td width="222">KCP Lodan Center (5285)</td>,
#  <td width="347">Ruko Lodan Center Ancol Blok O No. 6-7, Jln. Lodan Center. Jakarta, 14430</td>,
#  <td width="183">021-69831452</td>,
#  <td width="39">23</td>,
#  <td width="222">KCP Mahkota Ancol (5295)</td>,
#  <td width="347">Komplek Ruko Mahkota Ancol Blok E No.1, Pademangan. Jakarta, 14420</td>,
#  <td width="183">021-64701934</td>,
#  <td width="39">24</td>,
#  <td width="222">KCP Mal Kelapa Gading III (8705)</td>,
#  <td width="347">Gedung Mal Kelapa Gading III, Jln. Bulevar Kelapa Gaing Blok M. Jakarta, 14240</td>,
#  <td width="183">021-45853688, 45853689</td>,
#  <td width="39">25</td>,
#  <td width="222">KCP Mangga Dua (0160)</td>,
#  <td width="347">Pst.Perd.Grosir Psr Pagi Lt.2 Bl.KA No.001A-B,002&amp;012,Jl.Arteri M.D. Jakarta, 14430</td>,
#  <td width="183">021-6599380</td>,
#  <td colspan="4" style="text-align: center;">Bank BCA di Jakarta Utara</td>,
#  <td width="39">26</td>,
#  <td width="222">KCP Mangga Dua ITC (0480)</td>,
#  <td width="347">Gedung ITC Mangga Dua Lt.IV Blok B No.20-25, 29-32, Jln. Mangga Dua Raya. Jakarta, 14430</td>,
#  <td width="183">021-6015205, 6016171</td>,
#  <td width="39">27</td>,
#  <td width="222">KCU MANGGA DUA RAYA (0335)</td>,
#  <td width="347">Jl.Mangga Dua Raya Blok C-5 Kav. No.1. Jakarta, 14430</td>,
#  <td width="183">021-6011410 (hunting)</td>,
#  <td width="39">28</td>,
#  <td width="222">KCP Mangga Dua Square (5910)</td>,
#  <td width="347">Komp. Ruko Mangga Dua Square Blok G No. 8-9, Jln. Gunung Sahari Raya No. 1. Jakarta, 14430</td>,
#  <td width="183">021-62311379-80</td>,
#  <td width="39">29</td>,
#  <td width="222">KK Mangga Dua (0160)</td>,
#  <td width="347">Gedung Pusat Perdagangan Grosir Mangga Dua Lt.1 Blok KA No.11 Jl.Mangga Dua Raya, Jakarta Utara. Jakarta, 14440</td>,
#  <td width="183">021-62525627</td>,
#  <td width="39">30</td>,
#  <td width="222">KCP Menara Ancol (6350)</td>,
#  <td width="347">Jln. Pasir Putih Raya. Jakarta, 14430</td>,
#  <td width="183">021-6459765, 6459766</td>,
#  <td colspan="4" style="text-align: center;"><strong>Bank BCA di Jakarta Utara</strong></td>,
#  <td width="39">31</td>,
#  <td width="222">KCU MUARA KARANG (0069)</td>,
#  <td width="347">Jln. Muara Karang Timur Blok B VIII No.116-117. Jakarta, 14450</td>,
#  <td width="183">021-6679790 (hunting)</td>,
#  <td width="39">32</td>,
#  <td width="222">KCP Muara Karang 3 (0407)</td>,
#  <td width="347">Jln. Galeri Niaga Mediterania Blok X.3 Kav.No.A8.J, Pantai Indah Kapuk. Jakarta, 14460</td>,
#  <td width="183">021-5882943-44, 5882947</td>,
#  <td width="39">33</td>,
#  <td width="222">KCP Muara Karang Utara (8040)</td>,
#  <td width="347">Jln. Pluit Karang Utara no. 137 A &amp; 137 B, Blok A3 Kav. 11. Jakarta, 14450</td>,
#  <td width="183">021–</td>,
#  <td width="39">34</td>,
#  <td width="222">KCP Muara Karang 2 (6370)</td>,
#  <td width="347">Jl.Pluit Karang Blok D-7-U No.211A Kav 2. Jakarta , 14450</td>,
#  <td width="183">021-6623522, 6624645</td>,
#  <td width="39">35</td>,
#  <td width="222">KCP Pademangan (0487)</td>,
#  <td width="347">Jln. Pademangan II Gang 15 No.45, Jakut. Jakarta, 14410</td>,
#  <td width="183">021-6415104-06</td>,
#  <td colspan="4" style="text-align: center;">Bank BCA di Jakarta Utara</td>,
#  <td width="39">36</td>,
#  <td width="222">KCP Pantai Indah Kapuk (8740)</td>,
#  <td width="347">Jln. Pantai Indah Selatan I Blok DF No.1 &amp; 2. Jakarta, 14460</td>,
#  <td width="183">021-5881118</td>,
#  <td width="39">37</td>,
#  <td width="222">KCP Pantai Indah Kapuk II (8650)</td>,
#  <td width="347">Rukan Eksklusif Bukit Golf Mediterania Blok C No. 17, PIK. Jakarta, 14460</td>,
#  <td width="183">021-55965992</td>,
#  <td width="39">38</td>,
#  <td width="222">KCP Pasar Pagi Mangga Dua (6360)</td>,
#  <td width="347">Gedung Pusat Perdagangan Grosir Pasar Pagi Lt.III, Ruang No.4 (Banking), Jln. Mangga Dua Raya. Jakarta, 14430</td>,
#  <td width="183">021-6011109, 6284218</td>,
#  <td width="39">39</td>,
#  <td width="222">KCP Pelabuhan Tanjung Priok (6900)</td>,
#  <td width="347">Gedung Terminal Penumpang Nusantara Pura II, Jl. Panaitan, Pelabuhan Tanjung Priok. Jakarta, 14310</td>,
#  <td width="183">021-4372108</td>,
#  <td width="39">40</td>,
#  <td width="222">KCP Permata Kota (5215)</td>,
#  <td width="347">Ruko Permata Kota Blok A No. 10 Jl. Pangeran Tubagus Angke No. 170. Jakarta, 14450</td>,
#  <td width="183">021-66671662</td>,
#  <td colspan="4" style="text-align: center;"><strong>Bank BCA di Jakarta Utara</strong></td>,
#  <td width="39">41</td>,
#  <td width="222">KCU PLUIT (0168)</td>,
#  <td width="347">Jln. Pluit Selatan 200. Jakarta, 14440</td>,
#  <td width="183">021-6601718 (hunting)</td>,
#  <td width="39">42</td>,
#  <td width="222">KCP Pluit Kencana (0244)</td>,
#  <td width="347">Jln. Taman Pluit Kencana Selatan No. 1-3. Jakarta, 14440</td>,
#  <td width="183">021-6604691, 6690778</td>,
#  <td width="39">43</td>,
#  <td width="222">KCP Pluit Mega Mal (5810)</td>,
#  <td width="347">Jln. Pluit Permai Raya 60. Jakarta, 14450</td>,
#  <td width="183">021-6684102, 6624010</td>,
#  <td width="39">44</td>,
#  <td width="222">KCP Pluit Samudra (6020)</td>,
#  <td width="347">Jln. Pluit Samudra No. 9 Blok N Kav. 5. Jakarta, 14450</td>,
#  <td width="183">021-6628120</td>,
#  <td width="39">45</td>,
#  <td width="222">KCP Pluit Timur (0386)</td>,
#  <td width="347">Jln. Pluit Timur Blok L Barat Kav. 41-42 No.12A-14. Jakarta, 14450</td>,
#  <td width="183">021-6604221</td>,
#  <td colspan="4" style="text-align: center;">Bank BCA di Jakarta Utara</td>,
#  <td width="39">46</td>,
#  <td width="222">KCP Prima Sunter (6590)</td>,
#  <td width="347">Ruko Prima Sunter, Jln. Danau Sunter Utara No.A2-A3. Jakarta, 14350</td>,
#  <td width="183">021-6517255, 6513047</td>,
#  <td width="39">47</td>,
#  <td width="222">KCP PRJ Kemayoran (7530)</td>,
#  <td width="347">Gambir Expo Blok C-3A dan C-5 Pintu 2 Arena PRJ Kemayoran. Jakarta, 14410</td>,
#  <td width="183">021-26645289</td>,
#  <td width="39">48</td>,
#  <td width="222">KCP Puri Deltamas (6430)</td>,
#  <td width="347">Komplek Ruko Puri Deltamas Blok J No. 5, Jl. Bandengan Selatan No. 43. Jakarta, 14450</td>,
#  <td width="183">021-66603223</td>,
#  <td width="39">49</td>,
#  <td width="222">KCP Sunter (0093)</td>,
#  <td width="347">Jln. Agung Utara Raya Blok A 360 D No.50-51, Sunter Agung. Jakarta, 14350</td>,
#  <td width="183">021-64716327, 6518755</td>,
#  <td width="39">50</td>,
#  <td width="222">KCP Sunter Bisma (5820)</td>,
#  <td width="347">Pertokoan Paradise Blok J-1 No. 6 &amp; 7, Jl. Sunter Paradise 23. Jakarta, 14350</td>,
#  <td width="183">021-6518626</td>,
#  <td colspan="4" style="text-align: center;"><strong>Bank BCA di Jakarta Utara</strong></td>,
#  <td width="39">51</td>,
#  <td width="222">KCP Sunter Danau (0419)</td>,
#  <td width="347">Jln. Danau Agung 2 Blok E2 No. 1A, Sunter Podomoro. Jakarta, 14350</td>,
#  <td width="183">021-6400090-92</td>,
#  <td width="39">52</td>,
#  <td width="222">KCU SUNTER MALL (0428)</td>,
#  <td width="347">Jln. Danau Sunter Utara Blok G 7 III No.1-2, Sunter Podomoro. Jakarta, 14350</td>,
#  <td width="183">021-6400748, 6401851-52</td>,
#  <td width="39">53</td>,
#  <td width="222">KCP Taman Permata Indah II (7630)</td>,
#  <td width="347">Ruko Taman Permata Indah II Blok M No.27 Jl.Kampung Gusti Pejagalan. Jakarta, 14450</td>,
#  <td width="183">021-6681002,6619189</td>,
#  <td width="39">54</td>,
#  <td width="222">KCP Taman Sunter Indah (5000)</td>,
#  <td width="347">Taman Sunter Indah Blok KI-1/31. Jakarta, 14350</td>,
#  <td width="183">021-6500489, 6500630</td>,
#  <td width="39">55</td>,
#  <td width="222">KCU TANJUNG PRIOK (0007)</td>,
#  <td width="347">Jln. Enggano 22-23. Jakarta, 14310</td>,
#  <td width="183">021-4301312 (hunting)</td>,
#  <td colspan="4" style="text-align: center;">Bank BCA di Jakarta Utara</td>,
#  <td width="39">56</td>,
#  <td width="222">KCP Teluk Mas (0481)</td>,
#  <td width="347">Jln. Teluk Gong No. 9 &amp; 9A. Jakarta, 14450</td>,
#  <td width="183">021-6612075, 6628961</td>,
#  <td width="39">57</td>,
#  <td width="222">KCP WTC Mangga Dua (8790)</td>,
#  <td width="347">Komp. Ruko WTC Mangga Dua, Upper Ground Blok D No. 16, Jln. Mangga Dua Raya No. 8. Jakarta, 14430</td>,
#  <td width="183">021- 30017777</td>,
#  <td width="39">58</td>,
#  <td width="222">KCP Yos Sudarso (6910)</td>,
#  <td width="347">Komplek Yos Sudarso Megah, Jln. Yos Sudarso No. 1 Blok B No. 5. Jakarta, 14320</td>,
#  <td width="183">021-4368568, 43930065</td>]

# %%
td[0]
# Out:
# <td width="39">1</td>

# %%
url1 = a[0]['href']
resp1 = requests.get(url1)
html1 = resp.content
cb = bs(html1, 'html.parser')

# %%
len(kota)
# Out:
# 2256

# %%
url1 = a[0]['href']

# %%
response = urllib.request.urlopen(url1)
webContent = response.read().decode('UTF-8')
soup = bs(webContent,'html.parser', from_encoding='utf-8')
type(soup)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\bs4\__init__.py:226: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# bs4.BeautifulSoup

# %%
#webContent

# %%
#soup

# %%
import urllib.request, urllib.error, urllib.parse

url = 'http://www.alamatbank.com/kantor-bank-bca-di-jakarta-barat/'

response = urllib.request.urlopen(url)
webContent = response.read().decode('UTF-8')
soup = bs(webContent,'html.parser')

tabs = soup.find_all(class_='responsive-tabs')
table = tabs[0].find_all('table')
td = table[0].find_all('td')
raw_alamat = []
cabang = []
alamat = []
for i in range(len(td)):
    if len(td[i]) <= 1 :
        continue
    else :
        raw_alamat.append(td[i])

for i in range(0,len(raw_alamat),2) :
    cabang.append(raw_alamat[i])
for i in range(1,len(raw_alamat),2) :
    alamat.append(raw_alamat[i])
    
alamat
# Out:
# [<td>Jln. Asemka 27-30 <br/>
#   Jakarta Barat, JK 11110</td>,
#  <td>Jln. Daan Mogot No. 95 <br/>
#   Jakarta Barat, JK 11460</td>,
#  <td>Jln. Gajah Mada 112 B-C-D <br/>
#   Jakarta Barat, JK 11120</td>,
#  <td>Perum. Green Garden <br/>
#   Blok A.7 No.33-34 <br/>
#   Jakarta Barat, JK 11520</td>,
#  <td>Ruko Taman Kedoya Permai <br/>
#   Blok A 1A No.4-5, 1B, 2A, 2B <br/>
#   Jakarta Barat, JK 11530</td>,
#  <td>Gedung C3 LT.1-3 <br/>
#   Komplek Puri Indah Blok 02 No.1-3 <br/>
#   Kembangan <br/>
#   Jakarta Barat, JK 11610</td>,
#  <td>Jln. Tubagus Angke No. 10 ABC dan 11 H <br/>
#   Jakarta Barat, JK 11460</td>,
#  <td>Wisma Asia <br/>
#   Jln. S. Parman Kav. 79 <br/>
#   Jakarta Barat, JK 11420</td>]

# %%
2 // 3
# Out:
# 0

# %%
for i in range(0, 10, 2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
